# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("projectdata\Stage2DataFiles\RegularSeasonDetailedResults.csv")

# %%
df2018 = df[df.Season == 2018].copy()

# %%
Teams = pd.read_csv("projectdata\Stage2DataFiles\Teams.csv")

# %%
#Create dataframe of matchups with random winner and loser
rng = np.random.RandomState(123)
df2018["TeamID"] = 0
df2018["OppID"] = 0
df2018["W"] = 0
df2018["TScore"] = 0
df2018["OScore"] = 0
df2018["TFGM"] = 0
df2018["TFGA"] = 0
df2018["TFGM3"] = 0
df2018["TFGA3"] = 0
df2018["TFTM"] = 0
df2018["TFTA"] = 0
df2018["TOR"] = 0
df2018["TDR"] = 0
df2018["TAst"] = 0
df2018["TTO"] = 0
df2018["TStl"] = 0
df2018["TBlk"] = 0
df2018["TPF"] = 0
df2018["OFGM"] = 0
df2018["OFGA"] = 0
df2018["OFGM3"] = 0
df2018["OFGA3"] = 0
df2018["OFTM"] = 0
df2018["OFTA"] = 0
df2018["OOR"] = 0
df2018["ODR"] = 0
df2018["OAst"] = 0
df2018["OTO"] = 0
df2018["OStl"] = 0
df2018["OBlk"] = 0
df2018["OPF"] = 0
drop = list(df2018.columns)
for i in range(len(df2018)):
    rand = rng.randint(0,2)
    if rand == 0:
        df2018["TeamID"].iloc[i] = df2018.WTeamID.iloc[i]
        df2018["OppID"].iloc[i] = df2018.LTeamID.iloc[i]

    else:
        df2018["TeamID"].iloc[i] = df2018.LTeamID.iloc[i]
        df2018["OppID"].iloc[i] = df2018.WTeamID.iloc[i]

    if df2018["TeamID"].iloc[i] == df2018.WTeamID.iloc[i]:
        df2018["W"].iloc[i] = 1
        df2018["TScore"].iloc[i] = df2018.WScore.iloc[i]
        df2018["OScore"].iloc[i] = df2018.LScore.iloc[i]
        df2018["TFGM"].iloc[i] = df2018.WFGM.iloc[i]
        df2018["TFGA"].iloc[i] = df2018.WFGA.iloc[i]
        df2018["TFGM3"].iloc[i] = df2018.WFGM3.iloc[i]
        df2018["TFGA3"].iloc[i] = df2018.WFGA3.iloc[i]
        df2018["TFTM"].iloc[i] = df2018.WFTM.iloc[i]
        df2018["TFTA"].iloc[i] = df2018.WFTA.iloc[i]
        df2018["TOR"].iloc[i] = df2018.WOR.iloc[i]
        df2018["TDR"].iloc[i] = df2018.WDR.iloc[i]
        df2018["TAst"].iloc[i] = df2018.WAst.iloc[i]
        df2018["TTO"].iloc[i] = df2018.WTO.iloc[i]
        df2018["TStl"].iloc[i] = df2018.WStl.iloc[i]
        df2018["TBlk"].iloc[i] = df2018.WBlk.iloc[i]
        df2018["TPF"].iloc[i] = df2018.WPF.iloc[i]
        df2018["OFGM"].iloc[i] = df2018.LFGM.iloc[i]
        df2018["OFGA"].iloc[i] = df2018.LFGA.iloc[i]
        df2018["OFGM3"].iloc[i] = df2018.LFGM3.iloc[i]
        df2018["OFGA3"].iloc[i] = df2018.LFGA3.iloc[i]
        df2018["OFTM"].iloc[i] = df2018.LFTM.iloc[i]
        df2018["OFTA"].iloc[i] = df2018.LFTA.iloc[i]
        df2018["OOR"].iloc[i] = df2018.LOR.iloc[i]
        df2018["ODR"].iloc[i] = df2018.LDR.iloc[i]
        df2018["OAst"].iloc[i] = df2018.LAst.iloc[i]
        df2018["OTO"].iloc[i] = df2018.LTO.iloc[i]
        df2018["OStl"].iloc[i] = df2018.LStl.iloc[i]
        df2018["OBlk"].iloc[i] = df2018.LBlk.iloc[i]
        df2018["OPF"].iloc[i] = df2018.LPF.iloc[i]
    else:
        df2018["W"].iloc[i] = 0
        df2018["TScore"].iloc[i] = df2018.LScore.iloc[i]
        df2018["OScore"].iloc[i] = df2018.WScore.iloc[i]
        df2018["TFGM"].iloc[i] = df2018.LFGM.iloc[i]
        df2018["TFGA"].iloc[i] = df2018.LFGA.iloc[i]
        df2018["TFGM3"].iloc[i] = df2018.LFGM3.iloc[i]
        df2018["TFGA3"].iloc[i] = df2018.LFGA3.iloc[i]
        df2018["TFTM"].iloc[i] = df2018.LFTM.iloc[i]
        df2018["TFTA"].iloc[i] = df2018.LFTA.iloc[i]
        df2018["TOR"].iloc[i] = df2018.LOR.iloc[i]
        df2018["TDR"].iloc[i] = df2018.LDR.iloc[i]
        df2018["TAst"].iloc[i] = df2018.LAst.iloc[i]
        df2018["TTO"].iloc[i] = df2018.LTO.iloc[i]
        df2018["TStl"].iloc[i] = df2018.LStl.iloc[i]
        df2018["TBlk"].iloc[i] = df2018.LBlk.iloc[i]
        df2018["TPF"].iloc[i] = df2018.LPF.iloc[i]
        df2018["OFGM"].iloc[i] = df2018.WFGM.iloc[i]
        df2018["OFGA"].iloc[i] = df2018.WFGA.iloc[i]
        df2018["OFGM3"].iloc[i] = df2018.WFGM3.iloc[i]
        df2018["OFGA3"].iloc[i] = df2018.WFGA3.iloc[i]
        df2018["OFTM"].iloc[i] = df2018.WFTM.iloc[i]
        df2018["OFTA"].iloc[i] = df2018.WFTA.iloc[i]
        df2018["OOR"].iloc[i] = df2018.WOR.iloc[i]
        df2018["ODR"].iloc[i] = df2018.WDR.iloc[i]
        df2018["OAst"].iloc[i] = df2018.WAst.iloc[i]
        df2018["OTO"].iloc[i] = df2018.WTO.iloc[i]
        df2018["OStl"].iloc[i] = df2018.WStl.iloc[i]
        df2018["OBlk"].iloc[i] = df2018.WBlk.iloc[i]
        df2018["OPF"].iloc[i] = df2018.WPF.iloc[i]

# %%
df2018 = df2018.drop(list(df.columns),axis=1)
df2018.to_csv("2018RegularSeasonDetailedStats_Cleaned.csv")

# %%
#Create dictionaries for each stat, each dictionary contains each team and their average for the respective stat.
teams = np.array([df2018.TeamID.values,df2018.TeamID.values]).reshape(1,-1)
teams = np.unique(teams)
Score = {}
FGM ={}
FGA={}
FGM3={}
FGA3={}
FTM={}
FTA={}
OR={}
DR={}
Ast={}
TO={}
Stl={}
Blk={}
PF={}
for team in teams:
    for i,k,j in zip(["TScore","TFGM","TFGA","TFGM3","TFGA3","TFTM","TFTA","TOR","TDR","TAst","TTO","TStl","TBlk","TPF"]\
                   ,["OScore","OFGM","OFGA","OFGM3","OFGA3","OFTM","OFTA","OOR","ODR","OAst","OTO","OStl","OBlk","OPF"],\
                  [Score,FGM,FGA,FGM3,FGA3,FTM,FTA,OR,DR,Ast,TO,Stl,Blk,PF]):
        
        ary = df2018[df2018["TeamID"]==team][i].values
        ary = np.append(ary,df2018[df2018["OppID"]==team][k].values)
        j[team]=ary.mean()

# %%
df2018averages = pd.DataFrame.from_dict(data,orient="index")
df2018averages.to_csv("2018RegularSeasonTeamAverages.csv")
df2018averages.head()
# Out:
#           Score        FGM        FGA      FGM3       FGA3        FTM  \
# 1101  70.666667  25.518519  56.481481  6.481481  19.962963  13.148148
# 1102  66.689655  22.758621  56.103448  7.931034  24.413793  13.241379
# 1103  71.290323  24.677419  57.064516  9.451613  26.645161  12.483871
# 1104  72.352941  25.294118  55.205882  6.382353  19.676471  15.382353
# 1105  60.419355  21.709677  54.709677  5.870968  19.387097  11.129032
#
#             FTA         OR         DR        Ast         TO       Stl  \
# 1101  18.666667   9.037037  23.222222  13.888889  14.407407  7.148148
# 1102  17.931034   9.827586  22.689655  13.896552  12.758621  6.448276
# 1103  17.935484   9.580645  23.483871  12.935484  13.838710  5.967742
# 1104  22.882353  10.029412  26.264706  12.529412  14.147059  6.411765
# 1105  17.193548  10.806452  22.935484  10.967742  16.580645  3.967742
#
#            Blk        TPF
# 1101  3.629630  21.037037
# 1102  2.620690  18.137931
# 1103  2.387097  20.032258
# ...

# %%
df = df2018.copy()

# %%
#Make a dataframe of the matchups in df2018 with the season average stats for each team instead of the single game stats.
df["TScore"] = df['TeamID'].map(Score)
df["OScore"] = df['OppID'].map(Score)
df["TFGM"] = df['TeamID'].map(FGM)
df["OFGM"] = df['OppID'].map(FGM)
df["TFGA"] = df['TeamID'].map(FGA)
df["OFGA"] = df['OppID'].map(FGA)
df["TFGM3"] = df['TeamID'].map(FGM3)
df["OFGM3"] = df['OppID'].map(FGM3)
df["TFGA3"] = df['TeamID'].map(FGA3)
df["OFGA3"] = df['OppID'].map(FGA3)
df["TFTM"] = df['TeamID'].map(FTM)
df["OFTM"] = df['OppID'].map(FTM)
df["TFTA"] = df['TeamID'].map(FTA)
df["OFTA"] = df['OppID'].map(FTA)
df["TOR"] = df['TeamID'].map(OR)
df["OOR"] = df['OppID'].map(OR)
df["TDR"] = df['TeamID'].map(DR)
df["ODR"] = df['OppID'].map(DR)
df["TAst"] = df['TeamID'].map(Ast)
df["OAst"] = df['OppID'].map(Ast)
df["TTO"] = df['TeamID'].map(TO)
df["OTO"] = df['OppID'].map(TO)
df["TStl"] = df['TeamID'].map(Stl)
df["OStl"] = df['OppID'].map(Stl)
df["TBlk"] = df['TeamID'].map(Blk)
df["OBlk"] = df['OppID'].map(Blk)
df["TPF"] = df['TeamID'].map(PF)
df["OPF"] = df['OppID'].map(PF)
df.head()
# Out:
#        TeamID  OppID  W     TScore     OScore       TFGM       TFGA     TFGM3  \
# 76636    1272   1104  0  70.823529  72.352941  24.352941  53.882353  5.911765
# 76637    1233   1107  0  79.848485  73.322581  28.242424  61.121212  9.666667
# 76638    1112   1319  1  80.882353  65.033333  28.823529  57.029412  6.911765
# 76639    1226   1113  0  73.071429  83.516129  25.892857  54.714286  8.392857
# 76640    1359   1116  0  76.200000  81.088235  26.700000  57.500000  9.133333
#
#            TFGA3       TFTM  ...      OFGA3       OFTM       OFTA        OOR  \
# 76636  18.647059  16.205882  ...  19.676471  15.382353  22.882353  10.029412
# 76637  24.909091  13.696970  ...  15.516129  15.870968  21.032258  11.612903
# 76638  18.352941  16.323529  ...  18.233333  16.200000  23.133333   9.866667
# 76639  21.321429  12.892857  ...  24.548387  18.645161  25.258065   9.903226
# 76640  24.566667  13.666667  ...  19.441176  15.352941  22.647059  10.176471
#
# ...

# %%
df.to_csv("2018RegularSeasonDetailedResults_Averages.csv")

# %% [markdown]
# ## Messing around with KNN

# %%
X = df.drop(["TeamID","OppID","W","TScore","OScore"],axis=1).copy()
y = df["W"]

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split


X_train, X_val, y_train, y_val = train_test_split(X, y,
                                                          test_size=.3,
                                                          train_size=.7,
                                                         stratify=y)

# %%
knn = KNeighborsClassifier(n_neighbors=3)
knn.fit(X_train, y_train)
y_pred = knn.predict(X_val)
def error(y_val, y_pred):
    incorrect = 0
    for i, j in zip(y_val, y_pred):
        if i != j:
            incorrect += 1
    return 1-(incorrect/len(y_val))

error(y_train, y_pred)
# Out:
# 0.7798043880518107
